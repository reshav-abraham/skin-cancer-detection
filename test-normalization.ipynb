# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test_images = np.load("normalized-train-images.npy", allow_pickle=True)
test_labels = np.load("train-labels.npy", allow_pickle=True)

# %%
# https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib
labels = test_labels
rows = ['{}'.format(row) for row in labels]

fig, axes = plt.subplots(nrows=len(labels), ncols=2, figsize=(15, 15))

for ax, row in zip(axes[:,0], rows):
    ax.set_ylabel(row, rotation=0, size='large',labelpad=50)

count = 0
for idx, label in enumerate(labels):
    # image_array = df[df['dx']==label].iloc[j]['image_array']
    image_array = test_images[idx]
    axes[idx,0].imshow(image_array)
    axes[idx,0].tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
            left=False,
            labelleft=False,
            labelright=False,
            labeltop=False,
    labelbottom=False) # labels along the bottom edge are off

        #plt.axis('off')
        
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-615cc29f4fc6> in <module>
#       3 rows = ['{}'.format(row) for row in labels]
#       4
# ----> 5 fig, axes = plt.subplots(nrows=len(labels), ncols=2, figsize=(15, 15))
#       6
#       7 for ax, row in zip(axes[:,0], rows):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1210     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1211                        squeeze=squeeze, subplot_kw=subplot_kw,
# -> 1212                        gridspec_kw=gridspec_kw)
#    1213     return fig, axs
#    1214
#
# /usr/local/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
# ...

# %%
# https://machinelearningmastery.com/how-to-manually-scale-image-pixel-data-for-deep-learning/

# %%
test_images = np.divide(test_images, 255)
mean, std = test_images.mean(), test_images.std()

# %%
mean
# Out:
# 2.0842297311906042e-17

# %%
std
# Out:
# 0.003921568627450968

# %%
test_images = (test_images - mean) / std

# %%
test_images.mean(), test_images.std()
# Out:
# (2.98613617184237e-18, 1.000000000000001)

# %%
# https://stackoverflow.com/questions/41793931/plotting-images-side-by-side-using-matplotlib
labels = test_labels[:10]
rows = ['{}'.format(row) for row in labels]

fig, axes = plt.subplots(nrows=len(labels), ncols=2, figsize=(15, 15))

for ax, row in zip(axes[:,0], rows):
    ax.set_ylabel(row, rotation=0, size='large',labelpad=50)

count = 0
for idx, label in enumerate(labels):
    # image_array = df[df['dx']==label].iloc[j]['image_array']
    image_array = test_images[idx]
    axes[idx,0].imshow(image_array)
    axes[idx,0].tick_params(
    axis='both',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
            left=False,
            labelleft=False,
            labelright=False,
            labeltop=False,
    labelbottom=False) # labels along the bottom edge are off

        #plt.axis('off')
        
fig.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
